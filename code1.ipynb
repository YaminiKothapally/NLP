# %% [markdown]
# <a href="https://colab.research.google.com/github/YaminiKothapally/NLP/blob/main/code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
words = ["cats", "trouble", "troubling", "troubled", "having", "corriendo", "at", "was"]
for word in words:
    print('Word :', word, "\nStemmed Word :", stemmer.stem(word), '\nLemma :', lemmatizer.lemmatize(word), end='\n\n')
# Out:
# Word : cats
# Stemmed Word : cat
# Lemma : cat
#
# Word : trouble
# Stemmed Word : troubl
# Lemma : trouble
#
# Word : troubling
# Stemmed Word : troubl
# Lemma : troubling
#
# Word : troubled
# Stemmed Word : troubl
# Lemma : troubled
#
# Word : having
# Stemmed Word : have
# Lemma : having
#
# Word : corriendo
# Stemmed Word : corriendo
# Lemma : corriendo
#
# Word : at
# Stemmed Word : at
# Lemma : at
#
# Word : was
# Stemmed Word : wa
# Lemma : wa

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import re
import pandas as pd
from nltk.stem import PorterStemmer

def word_extraction(sentence):
    ignore = ['a', "the", "is"]
    words = re.sub("[^\w]", " ",  sentence).split()
    cleaned_text = [w.lower() for w in words if w not in ignore]
    return cleaned_text

stemmer = PorterStemmer()
text = "Text Summarization is one of those applications of Natural Language Processing (NLP) which is bound to have a huge impact on our lives. With growing digital media and ever-growing publishing – who has the time to go through entire articles / documents / books to decide whether they are useful or not? Thankfully – this technology is already here."
text = word_extraction(text)
data = pd.DataFrame(columns=['Word', 'Frequency', 'Stem', 'Lemma'])
for word in set(text):
    data.loc[len(data.index)] = [word, text.count(word), stemmer.stem(word), lemmatizer.lemmatize(word)]
data
# Out:
#              Word Frequency       Stem          Lemma
# 0            they         1       they           they
# 1         growing         2       grow        growing
# 2          entire         1      entir         entire
# 3              on         1         on             on
# 4         digital         1      digit        digital
# 5      technology         1  technolog     technology
# 6              to         3         to             to
# 7         through         1    through        through
# 8              of         2         of             of
# 9          useful         1        use         useful
# 10         impact         1     impact         impact
# 11            nlp         1        nlp            nlp
# 12           this         1        thi           this
# 13     processing         1    process     processing
# 14          those         1      those          those
# 15   applications         1     applic    application
# 16           huge         1       huge           huge
# 17           with         1       with           with
# 18           ever         1       ever           ever
# 19           here         1       here           here
# 20         decide         1      decid         decide
# 21          media         1      media         medium
# 22        already         1    alreadi        already
# 23          which         1      which          which
# 24           have         1       have           have
# 25            not         1        not            not
# 26            and         1        and            and
# 27            who         1        who            who
# 28     thankfully         1      thank     thankfully
# 29           text         1       text           text
# 30      documents         1   document       document
# 31        whether         1    whether        whether
# 32        natural         1      natur        natural
# 33             go         1         go             go
# 34            one         1        one            one
# 35           time         1       time           time
# 36          bound         1      bound          bound
# 37          books         1       book           book
# 38       articles         1     articl        article
# 39  summarization         1     summar  summarization
# 40             or         1         or             or
# 41            are         1        are            are
# 42            our         1        our            our
# 43     publishing         1    publish     publishing
# 44       language         1    languag       language
# 45            has         1         ha             ha
# 46          lives         1       live           life
